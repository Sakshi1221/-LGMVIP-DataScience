# %% [markdown]
# ##**Author:Sakshi Sanjay Sontakke**
# ##**Email:sakshisontakke0612@mail.com**
# ##**Task:Image to Pencil Sketch with Python**
# ##**@LetsGrowMore (VIP)**
# ##**Role:Data Science [Batch October-2021]**

# %% [markdown]
# ##**Table of Content**
#
# 1.Importing Essential Libraies:
#
# 2.Converting image into Gray Scale
#
# 3.Inverting image
#
# 4.Bluring the Image
#
# 5.Final sketch

# %% [markdown]
# ##**Importing Essential Libraies**:

# %%
import cv2

# %%
from  google.colab.patches import cv2_imshow

# %% [markdown]
# ##**Read The Image**

# %%
img=cv2.imread('/content/sample_data/kitten.jpg')

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=390x280 at 0x7FC87026CB10>

# %% [markdown]
# ##**Converting image into Gray Scale**

# %%
gray_scale_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_scale_img)
# Out:
# <PIL.Image.Image image mode=L size=390x280 at 0x7FC870275610>

# %% [markdown]
# ##**Inverting image**

# %%
inverted_img=cv2.bitwise_not(gray_scale_img)
cv2_imshow(inverted_img)
# Out:
# <PIL.Image.Image image mode=L size=390x280 at 0x7FC870256B90>

# %% [markdown]
# ##**Bluring the Image**

# %%
img_smoothing=cv2.GaussianBlur(inverted_img, (21 ,21),sigmaX=0, sigmaY=0)
cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=390x280 at 0x7FC8712B6690>

# %% [markdown]
# #**Final Sketch**

# %%
def dodgeV2(x,y):
  return cv2.divide(x, 255 - y, scale=256)

# %%
final_img=dodgeV2(gray_scale_img , img_smoothing)
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=390x280 at 0x7FC8712BF8D0>

# %% [markdown]
# #**THANK YOU**
